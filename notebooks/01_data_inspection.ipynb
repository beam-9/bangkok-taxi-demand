# %% [markdown]
# # 01 Data Inspection
#
# Inspect raw OTP taxi analytics, hotspot, and weather files after running `python src/download_data.py`.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
RAW = PROJECT_ROOT / 'data' / 'raw'
RAW

# %%
for path in RAW.glob('*.csv'):
    print(path.name)
    df = pd.read_csv(path)
    display(df.head())
    print(df.columns.tolist())
    print(df.shape)
