# %% [markdown]
# # 03 Modeling
#
# Train baseline and classical ML models, then inspect saved results.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))
from src.train_model import train_models

results = train_models()
results

# %%
predictions = pd.read_csv(PROJECT_ROOT / 'data' / 'processed' / 'test_predictions.csv', parse_dates=['date'])
predictions.head()
